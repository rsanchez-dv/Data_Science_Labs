# %% [markdown]
# # Welcome to the First Lab!

# %% [markdown]
# In this lab, we will learn how to make different kinds of graphs using python. Let's start by importing the data set. You should be able to find this file on the Google Drive, but if not, here is a link to the Kaggle website:

# %% [markdown]
# ## Part 1: Importing the Data and doing basic Exploratory Analysis

# %%
import pandas as pd

df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %% [markdown]
# ### Question 1:

# %% [markdown]
# You can use python to do basic EDA (Exploratory Data Analysis). This usually entails calculating the mean, median, mode, range, and standard deviation of a certain quantitative variable. Below, I will demonstrate with an example:

# %% [markdown]
# Say that we want to perform EDA on the age variable in our IBM data set.

# %%
#Mean:
# use .mean()
df['Age'].mean()
# Out:
# 36.923809523809524

# %%
#Median:
# use .median()
df['Age'].median()
# Out:
# 36.0

# %%
#Mode:
# use .mode()
df['Age'].mode()
# Out:
# 0    35
# dtype: int64

# %%
#Range:
# use .min() and .max() and subtract
df['Age'].max() - df['Age'].min()
# Out:
# 42

# %%
#Standard deviation:
# use .std()
df['Age'].std()
# Out:
# 9.135373489136734

# %% [markdown]
# #### Now, Calculate the EDA for three quantitative variables in the dataset (other than Age) of your choice. (Hint: use df.head()) to see the first 5 rows of all of the columns.

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df['DailyRate'].mean()
df['DailyRate'].mode()
df['DailyRate'].std()
df['Education'].mean()
df['Education'].mode()
df['Education'].std()
# Out:
# 1.0241649445978729

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# ## Part 2: Making Graphs Using Pandas

# %% [markdown]
# ### Pandas and Matplotlib
#
# <!--
# Talking points:
# In this lesson, we will introduce how plotting works in Pandas and Matplotlib. It is important to know that Pandas uses Matplotlib behind the scenes to make plots. So, you will notice that Pandas plotting methods often use similar parameter names as Matplotlib methods. Further, you can use Matplotlib functions in combination with Pandas methods to alter the plots after drawing them. For example, you can use Matplotlib's `xlabel` and `title` functions to label the plot's x-axis and title, respectively, after it is drawn.
# -->
#
# As we explore different types of plots, notice:
#
# 1. Different types of plots are drawn very similarly -- they even tend to share parameter names.
# 2. In Pandas, calling `plot()` on a `DataFrame` is different than calling it on a `Series`. Although the methods are both named `plot`, they may take different parameters.

# %% [markdown]
# ### Plotting with Pandas: How?
#
# `<data_set>.<columns>.plot()`
#
# `population.states.count().plot()` creates:
#
# ![](https://exceljet.net/sites/default/files/styles/original_with_watermark/public/images/charttypes/line%20chart2.png?itok=lG1hqRu4)

# %% [markdown]
# ### Plotting: Visualization Types
#
# Line charts are default.
#
# `# line chart`
#
# `population.states.count().plot()`
#
# For other charts:
#
# `population.states.plot(kind='bar')`
#
# `population.states.plot(kind='hist', bins=3);`
#
# `population.states.plot(kind='scatter', x='states', y='population')`
#
# Let's try!

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# set the plots to display in the Jupyter notebook
# %matplotlib inline

# Increase default figure and font sizes for easier viewing.
plt.rcParams['figure.figsize'] = (8, 6)
plt.rcParams['font.size'] = 14

# %% [markdown]
# ### Let's focus on the YearsAtCompany variable to start:

# %%
df['YearsAtCompany'].sort_index().value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Now, try plotting a bar plot for the TotalWorkingYears variable:

# %%
df['TotalWorkingYears'].sort_index().value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# <a id="histograms"></a>
# ## Histograms: Show the distribution of a numerical variable
# ---

# %% [markdown]
# ### How would you split the `YearsAtCompany` values into 3 equally sized bins?

# %%
df['YearsAtCompany'].unique()
# Out:
# array([ 6, 10,  0,  8,  2,  7,  1,  9,  5,  4, 25,  3, 12, 14, 22, 15, 27,
#        21, 17, 11, 13, 37, 16, 20, 40, 24, 33, 19, 36, 18, 29, 31, 32, 34,
#        26, 30, 23])

# %% [markdown]
# Use a histogram! The `bins=n` kwarg allows us to specify the number of bins ('buckets') of values.

# %%
df['YearsAtCompany'].plot(kind='hist', bins=3);
plt.ylabel('Number of Values')
plt.xlabel('Years')
plt.title('My Title');

# %% [markdown]
# Sometimes it is helpful to increase this number if you think you might have an outlier or a zero-weighted set.

# %%
# Now change the number of bins to 20.
df['YearsAtCompany'].plot(kind='hist', bins=20);
plt.ylabel('Number of Values')
plt.xlabel('Years')
plt.title('Change bin size');

# %% [markdown]
# ### Knowledge check:
# What does the y-axis represent on a histogram? What about the x-axis? How would you explain a histogram to a non-technical person?

# %% [markdown]
# ### Making histograms of an entire dataframe:

# %%
df.hist(figsize=(40,30));

# %% [markdown]
# ### Why doesn't it make plots of ALL the columns in the dataframe?
#
# Hint: what is different about the columns it plots vs. the ones it left out?

# %% [markdown]
# The ones left out did not contains numerical data.

# %% [markdown]
# ## Now, create a histogram of the `TotalWorkingYears` column, with 10 bins, and label both axes

# %%
df['TotalWorkingYears'].plot(kind='hist', bins=10);
plt.ylabel('Number of Values')
plt.xlabel('Total Working Years')
plt.title('TotalWorkingYears Histo');

# %% [markdown]
# Describe your histogram using shape, center and spread.

# %% [markdown]
# The histogram is skewed right, the center is located at x=~15, and spread is x=0 through x=40

# %% [markdown]
# ## Scatter plots: Show the relationship between two numerical variables

# %% [markdown]
# ### Below, let's see how to make a scatterplot by plotting x = Age and y = YearsAtCompany. This will allow us to see if there is a correlation between the age of the employee and how long they have been at the company.

# %% [markdown]
# What do you expect to see from these data?

# %% [markdown]
# Solution: We would expect to see a positive linear relationship between the two variables, because older people are more likely to have been at the company for longer.

# %%
df.plot(kind='scatter', x='Age', y='YearsAtCompany', \
        color='dodgerblue', figsize=(10,4), s=10, alpha=0.5)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='YearsAtCompany'>

# %% [markdown]
# Was your prediction correct?

# %%
The older the person is the longer they had stayed at the company but not as many people compared to the younger group.

# %% [markdown]
# ### Now, create a scatterplot that shows the correlation between employee age and TotalWorkingYears.

# %%
df.plot(kind='scatter', x='Age', y='TotalWorkingYears', \
        color='dodgerblue', figsize=(10,4), s=10, alpha=0.5)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='TotalWorkingYears'>

# %% [markdown]
# Does the plot align with what you'd expect? Compare it to the plot created in the example.

# %% [markdown]
# Yes, the total working years corolate with the age

# %% [markdown]
# We can also use a very handy parameter, `c`, which allows us to color the dots in a scatter plot. This is extremely helpful when doing **classification problems**, often you will set the color to the class label.
#
#
# Let's map the type field to the color of the dot in our YearsAtCompany scatterplot. To use the type field, we need to convert it from a string into a number. We can use pd.Series.apply() for this

# %%
df['Department'].unique()
mapping_dict = {}
initial_class_label = 0
for type in list(df['Department'].unique()):
    mapping_dict[type] = initial_class_label
    initial_class_label += 1
mapping_dict
# Out:
# {'Sales': 0, 'Research & Development': 1, 'Human Resources': 2}

# %% [markdown]
# Now we can use this `mapping_dict` dictionary to map the values using `.apply()`:

# %%
df['Department_as_num'] = df['Department'].apply(lambda x: mapping_dict[x])
df[['Department', 'Department_as_num']].head(3)
# Out:
#                Department  Department_as_num
# 0                   Sales                  0
# 1  Research & Development                  1
# 2  Research & Development                  1

# %% [markdown]
# Finally, we can use this **binary class label** as our `c` parameter to gain some insight:

# %%
df.plot(kind='scatter', x='Age', y='YearsAtCompany', \
        c='Department_as_num', colormap='winter', figsize=(8,4))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='YearsAtCompany'>

# %% [markdown]
# Amazing! It looks like the number of years at the company is not impacted by deparment.

# %% [markdown]
# ### Now, try performing a similar kind of analysis on the Age vs TotalWorkingYears scatterplot, with the c parameter set to BusinessTravel.

# %%
df['TotalWorkingYears'].unique()
mapping_dict2 = {}
initial_class_label2 = 0
for type in list(df['TotalWorkingYears'].unique()):
    mapping_dict2[type] = initial_class_label2
    initial_class_label2 += 1
mapping_dict2
# Out:
# {8: 0,
#  10: 1,
#  7: 2,
#  6: 3,
#  12: 4,
#  1: 5,
#  17: 6,
#  5: 7,
#  3: 8,
#  31: 9,
#  13: 10,
#  0: 11,
#  26: 12,
#  24: 13,
#  22: 14,
#  9: 15,
#  19: 16,
#  2: 17,
#  23: 18,
#  14: 19,
#  15: 20,
#  4: 21,
#  29: 22,
#  28: 23,
#  21: 24,
#  25: 25,
#  20: 26,
#  11: 27,
#  16: 28,
#  37: 29,
#  38: 30,
#  30: 31,
#  40: 32,
#  18: 33,
#  36: 34,
#  34: 35,
#  32: 36,
#  33: 37,
#  35: 38,
#  27: 39}

# %%
df['TotalWorkingYears_as_num'] = df['TotalWorkingYears'].apply(lambda x: mapping_dict2[x])
df[['TotalWorkingYears', 'TotalWorkingYears_as_num']].head(3)
# Out:
#    TotalWorkingYears  TotalWorkingYears_as_num
# 0                  8                         0
# 1                 10                         1
# 2                  7                         2

# %%
df.plot(kind='scatter', x='Age', y='TotalWorkingYears', \
        c='TotalWorkingYears_as_num', colormap='winter', figsize=(8,4))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='TotalWorkingYears'>

# %% [markdown]
# What do you notice about the plot?

# %% [markdown]
# The older the less they are apart of the company.
